# %%
import os
import sys

# 1. Force Python to read directly from your raw source code folder
cloned_source_path = "/home/jovyan/invest/src"
if cloned_source_path not in sys.path:
    sys.path.insert(0, cloned_source_path)

# 2. Try the import now
try:
    import natcap.invest.sdr.sdr
    print("🎉 Success! Python bypassed the compiler and successfully imported the module directly from your source directory!")
except ModuleNotFoundError as e:
    print(f"❌ Import failed. Error detail: {e}")
# Out:
# ❌ Import failed. Error detail: No module named 'geometamaker'

# %%
# %pip install geometamaker pyro5 chardet
# Out:
# ...
#   Using cached geometamaker-0.4.0-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached pyro5-5.17-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached chardet-7.6.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# ...
#   Using cached serpent-1.43-py3-none-any.whl.metadata (6.1 kB)
# ...
# Using cached geometamaker-0.4.0-py3-none-any.whl (35 kB)
# Using cached pyro5-5.17-py3-none-any.whl (79 kB)
# Using cached chardet-7.6.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
# Using cached serpent-1.43-py3-none-any.whl (9.8 kB)
# WARNING: Error parsing dependencies of prefect: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     kubernetes (>=9.0.0a1.0) ; extra == 'all_extras'
#                ~~~~~~~~~~^
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [geometamaker] [pyro5]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install "setuptools>=64" "wheel" "numpy<2" "Cython<3"

# %%
# !conda install -y --solver=classic -c conda-forge pygeoprocessing taskgraph shapely gdal

# %%
# %pip install -e /home/jovyan/invest --no-build-isolation
# Out:
# Obtaining file:///home/jovyan/invest
#   Checking if build backend supports build_editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Using cached altair-6.3.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached distinctipy-1.3.4-py3-none-any.whl.metadata (7.7 kB)
# ...
#   Using cached narwhals-2.26.0-py3-none-any.whl.metadata (15 kB)
# ...
# Using cached altair-6.3.0-py3-none-any.whl (797 kB)
# Using cached narwhals-2.26.0-py3-none-any.whl (474 kB)
# Using cached distinctipy-1.3.4-py3-none-any.whl (26 kB)
# ...
#   Building editable for natcap.invest (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building editable for natcap.invest (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [66 lines of output]
#       running editable_wheel
#       creating /tmp/pip-wheel-8m41be_2/.tmp-nil1j8yr/natcap.invest.egg-info
#       writing /tmp/pip-wheel-8m41be_2/.tmp-nil1j8yr/natcap.invest.egg-info/PKG-INFO
# ...

# %% [markdown]
# # Restart kernel

# %%
# !conda install -y -c conda-forge pygeoprocessing taskgraph shapely gdal
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: failed
#
# InvalidMatchSpec: Invalid spec 'conda-forge/linux-64::_openmp_mutex==4.5=3_kmp_llvm[md5=ee5c2118262e30b972bc0b4db8ef0ba5]': Libmamba only supports a subset of the MatchSpec interface for now. You can only use ('name', 'version', 'build', 'channel', 'subdir'), but you tried to use ('md5',).

# %%
import os
import sys

# Optional: If you haven't installed 'invest' globally, uncomment the line below 
# and point it to the parent directory containing your cloned repository
# sys.path.append(os.path.abspath("/home/jovyan/invest/src"))

import natcap.invest.sdr.sdr
import pprint

print("InVEST-SDR module successfully imported!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       2 import sys
#       4 # Optional: If you haven't installed 'invest' globally, uncomment the line below
#       5 # and point it to the parent directory containing your cloned repository
#       6 # sys.path.append(os.path.abspath("/home/jovyan/invest/src"))
# ----> 8 import natcap.invest.sdr.sdr
#       9 import pprint
#      11 print("InVEST-SDR module successfully imported!")
#
# ModuleNotFoundError: No module named 'natcap'
